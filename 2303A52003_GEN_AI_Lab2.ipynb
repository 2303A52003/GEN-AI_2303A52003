# %% [markdown]
# Consider a chocolate manufacturing company that produces only two types of chocolate i.e. A and B. Both the chocolates require Milk and Choco only. To manufacture each unit of A and B, the following quantities are required: Each unit of A requires 1 unit of Milk and 3 units of Choco Each unit of B requires 1 unit of Milk and 2 units of Choco The company kitchen has a total of 5 units of Milk and 12 units of Choco. On each sale, the company makes a profit of Rs 6 per unit A sold and Rs 5 per unit B sold. Now, the company wishes to maximize its profit. How many units of A and B should it produce respectively?

# %%
from scipy.optimize import linprog
import numpy as np
import matplotlib.pyplot as plt

c = [-6, -5]
A = [
    [1, 1],
    [3, 2]
]
b = [5, 12]
bounds = [(0, None), (0, None)]

result = linprog(c, A_ub=A, b_ub=b, bounds=bounds, method="highs")

if result.success:
    units_A, units_B = result.x
    print(f"Units of A to produce: {int(units_A)}")
    print(f"Units of B to produce: {int(units_B)}")
    print(f"Maximum Profit: Rs {-result.fun}")

    x = np.linspace(0, 10, 500)
    y1 = (5 - x)
    y2 = (12 - 3 * x) / 2

    plt.plot(x, y1, label="Milk constraint")
    plt.plot(x, y2, label="Choco constraint")
    plt.fill_between(x, np.minimum(y1, y2), color="gray", alpha=0.3, label="Feasible region")
    plt.scatter(units_A, units_B, color="red", label="Optimal solution")

    plt.xlim(0, 10)
    plt.ylim(0, 10)
    plt.xlabel("Units of A")
    plt.ylabel("Units of B")
    plt.legend()
    plt.title("Linear Programming Solution")
    plt.grid()
    plt.show()
else:
    print("No solution found.")
# Out:
# Units of A to produce: 2
# Units of B to produce: 3
# Maximum Profit: Rs 27.0

# %% [markdown]
# A farmer has recently acquired a 110 hectares piece of land. He has decided to grow Wheat and Barley on that land. Due to the quality of the sun and the region's excellent climate, the entire production of Wheat and Barley can be sold. He wants to know how to plant each variety in the 110 hectares, given the costs, net profits, and labor requirements according to the data shown below:
#
# Crop	Cost (Rs/Hec)	Profit (Price/Hec)	Man-days/Hec
# Wheat	7000	50	10
# Barley	2000	120	30
# The farmer has a budget of Rs. 7,00,000 and availability of 1,200 man-days during the planning horizon. Find the optimal solution and the optimal value.

# %%
from scipy.optimize import linprog
import numpy as np
import matplotlib.pyplot as plt

c = [-50, -120]
A = [
    [7000, 2000],
    [10, 30],
    [1, 1]
]
b = [700000, 1200, 110]
bounds = [(0, None), (0, None)]

result = linprog(c, A_ub=A, b_ub=b, bounds=bounds, method="highs")

if result.success:
    units_wheat, units_barley = result.x
    print(f"Hectares of Wheat to plant: {int(units_wheat)}")
    print(f"Hectares of Barley to plant: {int(units_barley)}")
    print(f"Maximum Profit: Rs {-result.fun}")
# Out:
# Hectares of Wheat to plant: 97
# Hectares of Barley to plant: 7
# Maximum Profit: Rs 5778.9473684210525

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 100, 400)
y_land = 110 - x
y_budget = (700000 - 7000*x) / 2000
y_labor = (1200 - 10*x) / 30

plt.figure(figsize=(8, 6))
plt.plot(x, y_land, label=r'$x + y \leq 100$', color='blue')
plt.plot(x, y_budget, label=r'$7000x + 2000y \leq 700000$', color='green')
plt.plot(x, y_labor, label=r'$10x + 30y \leq 1200$', color='red')
plt.fill_between(x, 0, np.minimum(np.minimum(y_land, y_budget), y_labor), where=(x >= 0) & (x <= 100), color='gray', alpha=0.5)

optimal_x = 80
optimal_y = 30
plt.plot(optimal_x, optimal_y, 'ko', label=f'Optimal Point ({optimal_x}, {optimal_y})')

plt.xlim(0, 100)
plt.ylim(0, 100)
plt.xlabel('Wheat (x)')
plt.ylabel('Barley (y)')
plt.title('Feasible Region and Optimal Solution')
plt.grid(True)
plt.legend()
plt.show()
